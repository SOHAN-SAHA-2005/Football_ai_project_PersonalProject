# %%
import os
HOME = os.getcwd()
print(HOME)

# %% [markdown]
# ## Install dependencies

# %%
# !pip install -q ultralytics roboflow

# %% [markdown]
# ## Imports

# %%
from roboflow import Roboflow
from google.colab import userdata
from IPython.display import Image

# %% [markdown]
# ## Pull dataset

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets


rf = Roboflow(api_key="wLH6ZHPIGayG72tw8Dyz")
project = rf.workspace("roboflow-jvuqo").project("football-field-detection-f07vi")
version = project.version(12)
dataset = version.download("yolov8")

# %%
# !sed -i 's|\(train: \).*|\1../train/images|' {dataset.location}/data.yaml
# !sed -i 's|\(val: \).*|\1../valid/images|' {dataset.location}/data.yaml

# %% [markdown]
# ## Custom training

# %%
# %cd {HOME}

# !yolo task=pose mode=train model=yolov8x-pose.pt data={dataset.location}/data.yaml batch=16 epochs=250 imgsz=640 mosaic=0.0 plots=True

# %%
# !ls {HOME}/runs/pose/train/

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/pose/train/results.png', width=600)

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/pose/train/val_batch0_pred.jpg', width=600)

# %% [markdown]
# ## Validate custom model

# %%
# %cd {HOME}

# !yolo task=pose mode=val model={HOME}/runs/pose/train/weights/best.pt data={dataset.location}/data.yaml
